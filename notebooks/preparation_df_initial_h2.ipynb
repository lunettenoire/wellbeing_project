# %%
import pandas as pd

#On part du df_2015
h2_1 = pd.read_csv("https://raw.githubusercontent.com/lunettenoire/wellbeing_project/refs/heads/main/data/cleaned/df_2015.csv")

h2_1
# Out:
#   Cell In[3], line 12
#     'freedom_to_make_life_choices",
#     ^
# SyntaxError: unterminated string literal (detected at line 12)
