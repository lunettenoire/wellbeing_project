# %%
import pandas as pd
df_2015 = pd.read_csv("df_original.csv")

# %%
# On garde uniquement les données depuis l'année 2015
df_2015 = df_2015[df_2015["year"] >= 2015]

# %%
# On exporte en csv
df_2015.to_csv("df_2015.csv", index=False)
